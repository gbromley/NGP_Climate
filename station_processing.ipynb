# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr

# %%
data_dir = '~gbromley/data/station_csv/'
station_file = pd.read_csv('~gbromley/dropbox/Montana_Climate_Project/NGP_stations.csv')

# %%
station_file
# Out:
#           Station      lat       lon  elevation
# 0     CA003010060  53.1167 -111.1833      658.0
# 1     CA003010160  52.4333 -111.7833      716.0
# 2     CA003010162  52.3167 -111.7833      737.0
# 3     CA003010164  52.3833 -111.8000      732.0
# 4     CA003010175  52.4167 -111.7833      713.0
# 5     CA003010232  52.6833 -111.1167      701.0
# 6     CA003010234  54.0167 -112.2333      610.0
# 7     CA003010237  53.9167 -112.2833      625.0
# 8     CA003010301  53.1333 -112.9500      747.0
# 9     CA003010535  52.6833 -112.8667      793.0
# 10    CA003010558  53.5333 -112.5333      770.0
# 11    CA003010650  52.5833 -111.4667      721.0
# 12    CA003010698  53.3833 -111.7667      689.0
# 13    CA003010704  53.0667 -113.0000      745.0
# 14    CA003010730  52.1167 -110.1000      687.0
# 15    CA003010810  53.5833 -113.2833      678.0
# 16    CA003010830  52.9833 -113.7167      815.0
# 17    CA003010890  52.3167 -111.4667      755.0
# 18    CA003010900  53.7833 -112.9333      640.0
# 19    CA003010978  54.0000 -113.8833      701.0
# 20    CA003010979  53.9333 -113.9167      714.0
# 21    CA003010991  52.2500 -110.5333      665.0
# 22    CA003010992  52.3333 -110.5167      690.0
# 23    CA003011120  53.2833 -113.8667      720.0
# 24    CA003011136  53.2333 -113.8000      671.0
# 25    CA003011138  53.2833 -113.8667      725.0
# 26    CA003011239  53.0333 -112.8000      675.0
# 27    CA003011240  53.0333 -112.8167      739.0
# 28    CA003011241  52.9500 -112.8000      738.0
# 29    CA003011440  52.2167 -111.9167      770.0
# ...           ...      ...       ...        ...
# 4768  USW00094023  44.3394 -105.5419     1327.1
# 4769  USW00094032  43.7331 -103.6114     1690.1
# 4770  USW00094037  45.6044 -103.5464      915.6
# 4771  USW00094038  46.0139 -102.6547      824.5
# 4772  USW00094039  43.0206 -102.5183      999.1
# 4773  USW00094041  47.6458 -101.4394      582.2
# 4774  USW00094051  47.3258 -106.9475      811.4
# 4775  USW00094052  45.5464 -100.4078      522.7
# 4776  USW00094053  42.0647 -104.1528     1281.7
# 4777  USW00094054  44.3814 -106.7211     1513.9
# 4778  USW00094055  46.3583 -104.2500      905.6
# 4779  USW00094056  45.0319 -102.0192      786.4
# 4780  USW00094059  48.4886 -105.2097      805.6
# 4781  USW00094060  48.3083 -105.1017      635.5
# 4782  USW00094077  42.4247 -103.7364     1342.9
# 4783  USW00094079  42.0681 -101.4450     1140.0
# 4784  USW00094080  46.8947 -103.3769      844.6
# 4785  USW00094081  45.5161 -103.3017      878.7
# 4786  USW00094084  48.9675 -102.1703      561.4
# 4787  USW00094085  44.0194 -100.3531      647.4
# 4788  USW00094088  44.5169 -104.4364     1765.4
# 4789  USW00094911  42.8783  -97.3633      359.7
# 4790  USW00094925  47.9667  -97.4000      276.1
# 4791  USW00094943  43.7667  -99.3183      519.1
# 4792  USW00094950  43.7667  -98.0333      397.2
# 4793  USW00094958  41.6236  -98.9517      630.6
# 4794  USW00094967  46.9006  -95.0678      437.1
# 4795  USW00094978  41.7636  -96.1778      313.3
# 4796  USW00094990  43.3906  -99.8422      619.4
# 4797  USW00094993  45.6689  -96.9914      353.9
#
# [4798 rows x 4 columns]

# %%
station_file['Station'][0]
# Out:
# 'CA003010060'

# %%
data = pd.read_csv(data_dir+station_file['Station'][0]+'.csv')

# %%
data.values.flatten().tolist()
# Out:
# [0,
#  'CA003010060',
#  2007,
#  5,
#  'TMAX',
#  121,
#  nan,
#  nan,
#  'C',
#  123,
#  nan,
#  nan,
#  'C',
#  163,
#  nan,
#  nan,
#  'C',
#  103,
#  nan,
#  nan,
#  'C',
#  158,
#  nan,
#  nan,
#  'C',
#  184,
#  nan,
#  nan,
#  'C',
#  191,
#  nan,
#  nan,
#  'C',
#  226,
#  nan,
#  nan,
#  'C',
#  142,
#  nan,
#  nan,
#  'C',
#  137,
#  nan,
#  nan,
#  'C',
#  217,
#  nan,
#  nan,
#  'C',
#  248,
#  nan,
#  nan,
#  'C',
#  160,
#  nan,
#  nan,
#  'C',
#  167,
#  nan,
#  nan,
#  'C',
#  198,
#  nan,
#  nan,
#  'C',
#  244,
#  nan,
#  nan,
#  'C',
#  236,
#  nan,
#  nan,
#  'C',
#  107,
#  nan,
#  nan,
#  'C',
#  73,
#  nan,
#  nan,
#  'C',
#  161,
#  nan,
#  nan,
#  'C',
#  118,
#  nan,
#  nan,
#  'C',
#  163,
#  nan,
#  nan,
#  'C',
#  147,
#  nan,
#  nan,
#  'C',
#  158,
#  nan,
#  nan,
#  'C',
#  161,
#  nan,
#  nan,
#  'C',
#  216,
#  nan,
#  nan,
#  'C',
#  234,
#  nan,
#  nan,
#  'C',
#  170,
#  nan,
#  nan,
#  'C',
#  146,
#  nan,
#  nan,
#  'C',
#  203,
#  nan,
#  nan,
#  'C',
#  245,
#  nan,
#  nan,
#  'C',
#  1,
#  'CA003010060',
#  2007,
#  5,
#  'TMIN',
#  -18,
#  nan,
#  nan,
#  'C',
#  65,
#  nan,
#  nan,
#  'C',
#  65,
#  nan,
#  nan,
#  'C',
#  36,
#  nan,
#  nan,
#  'C',
#  45,
#  nan,
#  nan,
#  'C',
#  25,
#  nan,
#  nan,
#  'C',
#  62,
#  nan,
#  nan,
#  'C',
#  68,
#  nan,
#  nan,
#  'C',
#  13,
#  nan,
#  nan,
#  'C',
#  -9,
#  nan,
#  nan,
#  'C',
#  9,
#  nan,
#  nan,
#  'C',
#  62,
#  nan,
#  nan,
#  'C',
#  2,
#  nan,
#  nan,
#  'C',
#  41,
#  nan,
#  nan,
#  'C',
#  -1,
#  nan,
#  nan,
#  'C',
#  71,
#  nan,
#  nan,
#  'C',
#  100,
#  nan,
#  nan,
#  'C',
#  33,
#  nan,
#  nan,
#  'C',
#  6,
#  nan,
#  nan,
#  'C',
#  45,
#  nan,
#  nan,
#  'C',
#  45,
#  nan,
#  nan,
#  'C',
#  49,
#  nan,
#  nan,
#  'C',
#  25,
#  nan,
#  nan,
#  'C',
#  12,
#  nan,
#  nan,
#  'C',
#  13,
#  nan,
#  nan,
#  'C',
#  26,
#  nan,
#  nan,
#  'C',
#  56,
#  nan,
#  nan,
#  'C',
#  106,
#  nan,
#  nan,
#  'C',
#  51,
#  nan,
#  nan,
#  'C',
#  18,
#  nan,
#  nan,
#  'C',
#  59,
#  nan,
#  nan,
#  'C',
#  2,
#  'CA003010060',
#  2007,
#  5,
#  'PRCP',
#  0,
#  nan,
#  nan,
#  'C',
#  18,
#  nan,
#  nan,
#  'C',
#  69,
#  nan,
#  nan,
#  'C',
#  33,
#  nan,
#  nan,
#  'C',
#  4,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  23,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  72,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  10,
#  nan,
#  nan,
#  'C',
#  60,
#  nan,
#  nan,
#  'C',
#  22,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  24,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  -9999,
#  nan,
#  nan,
#  nan,
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  3,
#  'CA003010060',
#  2007,
#  6,
#  'TMAX',
#  275,
#  nan,
#  nan,
#  'C',
#  297,
#  nan,
#  nan,
#  'C',
#  270,
#  nan,
#  nan,
#  'C',
#  259,
#  nan,
#  nan,
#  'C',
#  273,
#  nan,
#  nan,
#  'C',
#  163,
#  nan,
#  nan,
#  'C',
#  183,
#  nan,
#  nan,
#  'C',
#  208,
#  nan,
#  nan,
#  'C',
#  193,
#  nan,
#  nan,
#  'C',
#  200,
#  nan,
#  nan,
#  'C',
#  154,
#  nan,
#  nan,
#  'C',
#  136,
#  nan,
#  nan,
#  'C',
#  191,
#  nan,
#  nan,
#  'C',
#  196,
#  nan,
#  nan,
#  'C',
#  207,
#  nan,
#  nan,
#  'C',
#  216,
#  nan,
#  nan,
#  'C',
#  140,
#  nan,
#  nan,
#  'C',
#  204,
#  nan,
#  nan,
#  'C',
#  200,
#  nan,
#  nan,
#  'C',
#  -9999,
#  nan,
#  nan,
#  nan,
#  268,
#  nan,
#  nan,
#  'C',
#  227,
#  nan,
#  nan,
#  'C',
#  189,
#  nan,
#  nan,
#  'C',
#  200,
#  nan,
#  nan,
#  'C',
#  129,
#  nan,
#  nan,
#  'C',
#  175,
#  nan,
#  nan,
#  'C',
#  188,
#  nan,
#  nan,
#  'C',
#  206,
#  nan,
#  nan,
#  'C',
#  210,
#  nan,
#  nan,
#  'C',
#  225,
#  nan,
#  nan,
#  'C',
#  -9999,
#  nan,
#  nan,
#  nan,
#  4,
#  'CA003010060',
#  2007,
#  6,
#  'TMIN',
#  79,
#  nan,
#  nan,
#  'C',
#  97,
#  nan,
#  nan,
#  'C',
#  138,
#  nan,
#  nan,
#  'C',
#  87,
#  nan,
#  nan,
#  'C',
#  111,
#  nan,
#  nan,
#  'C',
#  80,
#  nan,
#  nan,
#  'C',
#  30,
#  nan,
#  nan,
#  'C',
#  95,
#  nan,
#  nan,
#  'C',
#  54,
#  nan,
#  nan,
#  'C',
#  83,
#  nan,
#  nan,
#  'C',
#  102,
#  nan,
#  nan,
#  'C',
#  57,
#  nan,
#  nan,
#  'C',
#  78,
#  nan,
#  nan,
#  'C',
#  79,
#  nan,
#  nan,
#  'C',
#  67,
#  nan,
#  nan,
#  'C',
#  62,
#  nan,
#  nan,
#  'C',
#  100,
#  nan,
#  nan,
#  'C',
#  79,
#  nan,
#  nan,
#  'C',
#  98,
#  nan,
#  nan,
#  'C',
#  -9999,
#  nan,
#  nan,
#  nan,
#  110,
#  nan,
#  nan,
#  'C',
#  94,
#  nan,
#  nan,
#  'C',
#  87,
#  nan,
#  nan,
#  'C',
#  78,
#  nan,
#  nan,
#  'C',
#  89,
#  nan,
#  nan,
#  'C',
#  77,
#  nan,
#  nan,
#  'C',
#  50,
#  nan,
#  nan,
#  'C',
#  87,
#  nan,
#  nan,
#  'C',
#  127,
#  nan,
#  nan,
#  'C',
#  114,
#  nan,
#  nan,
#  'C',
#  -9999,
#  nan,
#  nan,
#  nan,
#  5,
#  'CA003010060',
#  2007,
#  6,
#  'PRCP',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  203,
#  nan,
#  nan,
#  'C',
#  25,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  378,
#  nan,
#  nan,
#  'C',
#  158,
#  nan,
#  nan,
#  'C',
#  50,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  6,
#  nan,
#  nan,
#  'C',
#  9,
#  nan,
#  nan,
#  'C',
#  31,
#  nan,
#  nan,
#  'C',
#  15,
#  nan,
#  nan,
#  'C',
#  -9999,
#  nan,
#  nan,
#  nan,
#  7,
#  nan,
#  nan,
#  'C',
#  30,
#  nan,
#  nan,
#  'C',
#  4,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  306,
#  nan,
#  nan,
#  'C',
#  11,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  10,
#  nan,
#  nan,
#  'C',
#  -9999,
#  nan,
#  nan,
#  nan,
#  6,
#  'CA003010060',
#  2007,
#  6,
#  'SNWD',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  0,
#  nan,
#  nan,
#  'C',
#  -9999,
#  nan,
#  nan,
#  nan,
#  7,
#  'CA003010060',
#  2007,
#  7,
#  'TMAX',
#  225,
#  nan,
#  nan,
#  'C',
#  256,
#  nan,
#  nan,
#  'C',
#  273,
#  nan,
#  nan,
#  'C',
#  259,
#  nan,
#  nan,
#  'C',
#  308,
#  nan,
#  nan,
#  'C',
#  247,
#  nan,
#  nan,
#  'C',
#  226,
#  nan,
#  nan,
#  'C',
#  237,
#  nan,
#  nan,
#  'C',
#  178,
#  nan,
#  nan,
#  'C',
#  226,
#  nan,
#  nan,
#  'C',
#  260,
#  nan,
#  nan,
#  'C',
#  292,
#  nan,
#  nan,
#  'C',
#  315,
#  nan,
#  nan,
#  'C',
#  331,
#  nan,
#  nan,
#  'C',
#  302,
#  nan,
#  nan,
#  'C',
#  284,
#  nan,
#  nan,
#  'C',
#  287,
#  nan,
#  nan,
#  'C',
#  282,
#  nan,
#  nan,
#  'C',
#  328,
#  nan,
#  nan,
#  'C',
#  309,
#  nan,
#  nan,
#  'C',
#  289,
#  nan,
#  nan,
#  'C',
#  318,
#  nan,
#  nan,
#  'C',
#  349,
#  nan,
#  nan,
#  'C',
#  ...]

# %%
list(test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-350ef7f2b59f> in <module>()
# ----> 1 list(test)
#
# TypeError: 'builtin_function_or_method' object is not iterable
