# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fallow_data = pd.read_csv('/Users/gbromley/Dropbox/Montana_Climate_Project/fallow_combined.csv')

# %%
fallow_data['can_fallow']= fallow_data['can_fallow']/(1000000)

# %%
fallow_data.set_index('year')
# Out:
#       us_fallow  can_fallow
# year
# 1910          4   -0.009999
# 1911          5   -0.009999
# 1912          5   -0.009999
# 1913          5    3.919000
# 1914          5    3.809000
# 1915          5    3.762000
# 1916          5    3.771000
# 1917          5    6.293000
# 1918          5    7.204000
# 1919          5    7.464000
# 1920          5    6.996000
# 1921          6    9.796000
# 1922          6    9.460000
# 1923          6    9.624000
# 1924          6    9.068000
# 1925          7    9.594000
# 1926          8    9.921000
# 1927          9   10.678000
# 1928         10   10.132000
# 1929         10   11.101000
# 1930         11   11.744000
# 1931         11   12.398000
# 1932         12   12.993000
# 1933         14   14.389000
# 1934         15   14.901000
# 1935         16   14.252000
# 1936         18   16.854000
# 1937         20   15.150000
# 1938         19   16.206000
# 1939         21   15.950000
# ...         ...         ...
# 1987         32   21.400000
# ...

# %%
fig, ax = plt.subplots()
ax.plot(fallow_data['year'], fallow_data['can_fallow'], color='purple', label='Canada')
ax.plot(fallow_data['year'], fallow_data['us_fallow'], color='red', label='US')
ax.set_ylabel('Million Hectares')
ax.set_xlabel('Year')
ax.legend(loc=2)
fig.set_dpi(300)
fig.tight_layout()
plt.savefig('/Users/gbromley/Dropbox/Montana_Climate_Project/fallow_plot.png')
